# %%
import requests
import pandas as pd

csv_file_path = "tematicas_wallmart.csv"

headers = {
           'Authorization': 'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ0b2tlbiI6Im0xZF93bV9qd3QifQ.j0RUDD5jc8z14FRHQzgu_Ic0cKjE-FQOoySmxOEtox4'
           }

# Parámetros y encabezados para la solicitud POST
url = "https://m1h-api.onrender.com/clusterize"

# Abrir el archivo CSV y enviarlo en la solicitud POST
with open(csv_file_path, 'rb') as f:
    files = {'csv_file': (csv_file_path, f)}
    response = requests.post(url, headers=headers,files=files)

# Verificar la respuesta
if response.status_code == 200:
    # Guardar el archivo
    print(response.text)
else:
    print("Error:", response.status_code, response.text)
# Out:
# {"tags":[20,21,13,24,4,12,14,1,33,-1,13,1,1,1,3,14,-1,31,8,1,32,10,23,7,-1,3,17,1,7,13,-1,3,3,17,2,2,21,0,8,-1,1,12,19,3,9,31,6,2,1,0,0,7,-1,-1,23,5,11,0,22,14,1,5,29,7,11,31,26,2,26,-1,1,10,10,9,0,18,33,17,0,-1,-1,0,1,-1,4,13,13,0,0,0,0,35,6,7,5,13,7,0,1,1,-1,0,1,1,0,0,5,-1,40,31,31,-1,-1,12,29,0,0,19,0,1,41,1,0,0,1,0,0,41,25,27,2,14,3,12,12,5,5,1,0,11,26,0,26,0,-1,-1,0,3,-1,-1,20,33,29,0,0,16,0,8,15,11,-1,26,1,-1,0,4,0,-1,4,22,0,0,1,7,16,20,1,2,13,14,14,0,-1,7,13,-1,10,0,1,-1,7,0,1,0,4,1,7,3,1,8,4,0,12,0,8,25,1,1,5,2,-1,7,16,16,12,18,0,0,7,2,17,21,0,0,12,4,27,5,9,0,15,26,12,0,32,10,0,27,0,26,0,0,7,31,8,14,4,41,11,-1,3,4,12,0,24,0,31,16,13,-1,3,0,36,1,26,14,10,35,11,0,1,4,9,18,29,33,0,0,1,13,0,23,16,1,9,41,-1,3,17,0,-1,-1,0,35,1,10,-1,5,0,13,23,0,1,0,-1,-1,13,24,-1,0,22,15,-1,17,7,8,15,7,0,0,31,26,-1,-1,9,1,7,36,10,14,0,1,20,15,17,22,14,30,20,7,27,25,11,19,13,0,1,1,12,9,2,25,23,23,13,17,9,8,16,14,5,16,1,0,0,0,0,2,15,12,24,0,1,1,8,22,25,25,1,5,5,14,12,7,5,8,22,2,29,14,3,1,25,1,7,5,15,4,13,1,0,0,-1,4,12,8,-1,-1,20,22,20,-1,25,0,0,26,0,15,2,-1,5,0,3,36,26,27,1,10,-1,5,35,1,27,0,13,-1,29,32,20,21,-1,-1,-1,23,1,23,8,2,0,5,21,2,1,0,17,14,1,13,-1,14,-1,2,40,2,0,3,3,13,0,40,31,33,15,14,-1,14,15,-1,3,1,0,-1,1,16,9,7,26,0,33,19,-1,24,24,20,27,20,2,-1,32,19,-1,1,0,15,28,5,0,28,13,0,-1,28,12,36,-1,19,40,-1,0,2,20,1,-1,34,1,29,0,-1,-1,14,11,-1,0,0,3,3,-1,9,9,20,0,-1,19,-1,28,9,0,7,30,1,36,31,2,0,26,35,0,19,0,8,2,0,23,8,8,14,8,3,36,33,9,36,0,0,-1,-1,0,-1,2,8,-1,24,35,14,23,9,8,0,-1,-1,-1,22,9,6,35,26,7,-1,-1,0,0,12,0,7,36,2,18,11,13,0,2,0,-1,33,8,1,1,0,1,0,-1,11,0,36,0,8,2,24,0,9,20,21,19,19,0,35,0,8,2,20,28,-1,32,0,1,2,7,19,28,0,26,-1,-1,0,19,8,0,13,25,30,0,0,33,7,13,-1,7,22,22,2,3,-1,5,0,9,-1,0,12,-1,1,21,2,20,32,7,9,9,40,17,22,23,3,28,0,-1,-1,8,11,0,0,0,11,0,7,14,1,3,-1,1,5,11,21,24,34,32,18,1,-1,24,32,14,22,19,-1,0,36,28,11,28,23,-1,21,7,0,-1,4,1,19,0,-1,10,0,0,20,0,20,7,3,32,-1,-1,17,1,-1,8,-1,23,-1,7,27,35,0,22,-1,18,14,16,34,1,36,14,-1,0,0,15,28,28,0,7,7,7,3,6,1,29,0,0,34,34,7,14,0,0,0,3,0,2,24,34,30,1,9,1,0,29,4,21,4,3,3,0,23,3,7,11,5,18,1,-1,26,1,15,0,10,20,-1,7,13,24,25,10,8,0,0,3,24,28,22,24,1,5,24,14,9,29,11,0,0,14,9,3,0,1,1,0,0,-1,13,1,30,35,5,1,25,3,7,11,3,1,0,-1,0,21,29,2,11,-1,-1,-1,-1,11,28,30,15,24,5,22,1,9,1,5,0,34,1,0,0,15,13,3,36,4,32,27,0,36,0,-1,40,0,5,5,22,0,-1,-1,3,13,11,29,33,2,3,22,34,-1,0,0,22,0,9,0,-1,12,0,24,0,7,2,0,2,-1,23,10,34,7,2,2,25,1,14,13,3,-1,0,4,1,30,7,0,32,13,2,8,2,3,15,-1,3,21,0,14,1,-1,15,5,0,5,-1,33,-1,5,36,9,3,-1,0,22,29,-1,-1,-1,11,0,14,21,0,13,16,-1,36,21,9,20,1,32,15,12,1,10,15,-1,11,19,11,2,11,30,3,0,0,-1,1,1,0,22,1,1,11,20,17,0,1,0,24,3,8,11,1,0,15,0,-1,7,10,28,6,25,-1,1,23,1,-1,1,6,6,0,26,13,-1,24,0,10,4,5,29,7,2,10,13,13,1,1,0,1,23,4,1,-1,14,4,20,1,18,-1,3,-1,14,0,0,8,17,0,0,15,-1,0,16,1,4,3,1,3,-1,8,34,10,4,13,14,35,1,24,1,30,-1,1,7,18,32,-1,32,1,27,0,-1,-1,0,9,3,0,22,1,0,13,21,1,9,27,6,5,1,0,-1,0,6,2,-1,5,-1,1,0,17,15,15,1,1,0,28,1,1,31,10,0,9,0,1,0,34,14,0,2,8,29,12,19,0,3,23,0,0,7,-1,-1,14,-1,0,1,9,17,35,-1,0,31,-1,22,17,17,29,4,7,1,25,40,0,20,31,31,-1,5,0,8,17,17,4,-1,10,0,13,32,9,23,41,16,-1,3,20,13,26,4,21,16,0,27,1,0,0,28,0,23,-1,19,15,0,2,18,26,1,23,0,15,41,18,14,0,0,1,1,26,-1,1,2,25,-1,0,6,6,14,0,0,21,-1,6,10,0,31,12,25,14,27,14,11,27,29,5,34,11,28,15,5,0,18,1,6,3,10,25,26,29,0,3,0,10,9,-1,3,27,17,24,-1,1,1,10,0,9,14,1,-1,-1,20,0,4,9,7,13,1,7,29,14,0,5,35,0,0,-1,19,25,25,25,18,10,0,1,34,22,1,22,17,-1,4,8,0,0,0,0,0,41,31,4,12,-1,-1,14,29,8,10,29,33,24,24,0,26,18,3,18,4,2,-1,0,0,3,16,20,8,20,-1,29,5,-1,3,0,31,4,7,0,19,21,21,8,16,3,6,5,22,11,6,-1,14,12,1,32,1,-1,1,12,21,1,6,7,10,18,0,29,35,20,1,1,-1,2,4,-1,2,9,-1,1,9,9,27,-1,25,0,0,18,3,0,-1,4,0,0,0,1,20,3,13,-1,20,1,23,41,3,13,-1,-1,20,11,10,27,10,1,13,0,24,7,6,27,9,29,0,28,0,-1,14,32,17,21,0,-1,3,11,12,12,1,15,6,13,-1,-1,23,0,-1,1,-1,5,0,13,1,16,-1,29,0,29,10,10,0,9,27,19,-1,9,18,34,3,-1,16,26,1,1,15,12,4,-1,17,-1,3,18,0,0,11,10,0,0,8,40,0,17,34,1,-1,1,3,0,22,23,3,1,5,-1,4,40,28,26,2,-1,16,33,8,26,3,22,10,10,8,32,5,16,2,3,-1,1,0, ...

# %%
response.json()
# Out:
# {'tags': [20,
#   21,
#   13,
#   24,
#   4,
#   12,
#   14,
#   1,
#   33,
#   -1,
#   13,
#   1,
#   1,
#   1,
#   3,
#   14,
#   -1,
#   31,
#   8,
#   1,
#   32,
#   10,
#   23,
#   7,
#   -1,
#   3,
#   17,
#   1,
#   7,
#   13,
#   -1,
#   3,
#   3,
#   17,
#   2,
#   2,
#   21,
#   0,
#   8,
#   -1,
#   1,
#   12,
#   19,
#   3,
#   9,
#   31,
#   6,
#   2,
#   1,
#   0,
#   0,
#   7,
#   -1,
#   -1,
#   23,
#   5,
#   11,
#   0,
#   22,
#   14,
#   1,
#   5,
#   29,
#   7,
#   11,
#   31,
#   26,
#   2,
#   26,
#   -1,
#   1,
#   10,
#   10,
#   9,
#   0,
#   18,
#   33,
#   17,
#   0,
#   -1,
#   -1,
#   0,
#   1,
#   -1,
#   4,
#   13,
#   13,
#   0,
#   0,
#   0,
#   0,
#   35,
#   6,
#   7,
#   5,
#   13,
#   7,
#   0,
#   1,
#   1,
#   -1,
#   0,
#   1,
#   1,
#   0,
#   0,
#   5,
#   -1,
#   40,
#   31,
#   31,
#   -1,
#   -1,
#   12,
#   29,
#   0,
#   0,
#   19,
#   0,
#   1,
#   41,
#   1,
#   0,
#   0,
#   1,
#   0,
#   0,
#   41,
#   25,
#   27,
#   2,
#   14,
#   3,
#   12,
#   12,
#   5,
#   5,
#   1,
#   0,
#   11,
#   26,
#   0,
#   26,
#   0,
#   -1,
#   -1,
#   0,
#   3,
#   -1,
#   -1,
#   20,
#   33,
#   29,
#   0,
#   0,
#   16,
#   0,
#   8,
#   15,
#   11,
#   -1,
#   26,
#   1,
#   -1,
#   0,
#   4,
#   0,
#   -1,
#   4,
#   22,
#   0,
#   0,
#   1,
#   7,
#   16,
#   20,
#   1,
#   2,
#   13,
#   14,
#   14,
#   0,
#   -1,
#   7,
#   13,
#   -1,
#   10,
#   0,
#   1,
#   -1,
#   7,
#   0,
#   1,
#   0,
#   4,
#   1,
#   7,
#   3,
#   1,
#   8,
#   4,
#   0,
#   12,
#   0,
#   8,
#   25,
#   1,
#   1,
#   5,
#   2,
#   -1,
#   7,
#   16,
#   16,
#   12,
#   18,
#   0,
#   0,
#   7,
#   2,
#   17,
#   21,
#   0,
#   0,
#   12,
#   4,
#   27,
#   5,
#   9,
#   0,
#   15,
#   26,
#   12,
#   0,
#   32,
#   10,
#   0,
#   27,
#   0,
#   26,
#   0,
#   0,
#   7,
#   31,
#   8,
#   14,
#   4,
#   41,
#   11,
#   -1,
#   3,
#   4,
#   12,
#   0,
#   24,
#   0,
#   31,
#   16,
#   13,
#   -1,
#   3,
#   0,
#   36,
#   1,
#   26,
#   14,
#   10,
#   35,
#   11,
#   0,
#   1,
#   4,
#   9,
#   18,
#   29,
#   33,
#   0,
#   0,
#   1,
#   13,
#   0,
#   23,
#   16,
#   1,
#   9,
#   41,
#   -1,
#   3,
#   17,
#   0,
#   -1,
#   -1,
#   0,
#   35,
#   1,
#   10,
#   -1,
#   5,
#   0,
#   13,
#   23,
#   0,
#   1,
#   0,
#   -1,
#   -1,
#   13,
#   24,
#   -1,
#   0,
#   22,
#   15,
#   -1,
#   17,
#   7,
#   8,
#   15,
#   7,
#   0,
#   0,
#   31,
#   26,
#   -1,
#   -1,
#   9,
#   1,
#   7,
#   36,
#   10,
#   14,
#   0,
#   1,
#   20,
#   15,
#   17,
#   22,
#   14,
#   30,
#   20,
#   7,
#   27,
#   25,
#   11,
#   19,
#   13,
#   0,
#   1,
#   1,
#   12,
#   9,
#   2,
#   25,
#   23,
#   23,
#   13,
#   17,
#   9,
#   8,
#   16,
#   14,
#   5,
#   16,
#   1,
#   0,
#   0,
#   0,
#   0,
#   2,
#   15,
#   12,
#   24,
#   0,
#   1,
#   1,
#   8,
#   22,
#   25,
#   25,
#   1,
#   5,
#   5,
#   14,
#   12,
#   7,
#   5,
#   8,
#   22,
#   2,
#   29,
#   14,
#   3,
#   1,
#   25,
#   1,
#   7,
#   5,
#   15,
#   4,
#   13,
#   1,
#   0,
#   0,
#   -1,
#   4,
#   12,
#   8,
#   -1,
#   -1,
#   20,
#   22,
#   20,
#   -1,
#   25,
#   0,
#   0,
#   26,
#   0,
#   15,
#   2,
#   -1,
#   5,
#   0,
#   3,
#   36,
#   26,
#   27,
#   1,
#   10,
#   -1,
#   5,
#   35,
#   1,
#   27,
#   0,
#   13,
#   -1,
#   29,
#   32,
#   20,
#   21,
#   -1,
#   -1,
#   -1,
#   23,
#   1,
#   23,
#   8,
#   2,
#   0,
#   5,
#   21,
#   2,
#   1,
#   0,
#   17,
#   14,
#   1,
#   13,
#   -1,
#   14,
#   -1,
#   2,
#   40,
#   2,
#   0,
#   3,
#   3,
#   13,
#   0,
#   40,
#   31,
#   33,
#   15,
#   14,
#   -1,
#   14,
#   15,
#   -1,
#   3,
#   1,
#   0,
#   -1,
#   1,
#   16,
#   9,
#   7,
#   26,
#   0,
#   33,
#   19,
#   -1,
#   24,
#   24,
#   20,
#   27,
#   20,
#   2,
#   -1,
#   32,
#   19,
#   -1,
#   1,
#   0,
#   15,
#   28,
#   5,
#   0,
#   28,
#   13,
#   0,
#   -1,
#   28,
#   12,
#   36,
#   -1,
#   19,
#   40,
#   -1,
#   0,
#   2,
#   20,
#   1,
#   -1,
#   34,
#   1,
#   29,
#   0,
#   -1,
#   -1,
#   14,
#   11,
#   -1,
#   0,
#   0,
#   3,
#   3,
#   -1,
#   9,
#   9,
#   20,
#   0,
#   -1,
#   19,
#   -1,
#   28,
#   9,
#   0,
#   7,
#   30,
#   1,
#   36,
#   31,
#   2,
#   0,
#   26,
#   35,
#   0,
#   19,
#   0,
#   8,
#   2,
#   0,
#   23,
#   8,
#   8,
#   14,
#   8,
#   3,
#   36,
#   33,
#   9,
#   36,
#   0,
#   0,
#   -1,
#   -1,
#   0,
#   -1,
#   2,
#   8,
#   -1,
#   24,
#   35,
#   14,
#   23,
#   9,
#   8,
#   0,
#   -1,
#   -1,
#   -1,
#   22,
#   9,
#   6,
#   35,
#   26,
#   7,
#   -1,
#   -1,
#   0,
#   0,
#   12,
#   0,
#   7,
#   36,
#   2,
#   18,
#   11,
#   13,
#   0,
#   2,
#   0,
#   -1,
#   33,
#   8,
#   1,
#   1,
#   0,
#   1,
#   0,
#   -1,
#   11,
#   0,
#   36,
#   0,
#   8,
#   2,
#   24,
#   0,
#   9,
#   20,
#   21,
#   19,
#   19,
#   0,
#   35,
#   0,
#   8,
#   2,
#   20,
#   28,
#   -1,
#   32,
#   0,
#   1,
#   2,
#   7,
#   19,
#   28,
#   0,
#   26,
#   -1,
#   -1,
#   0,
#   19,
#   8,
#   0,
#   13,
#   25,
#   30,
#   0,
#   0,
#   33,
#   7,
#   13,
#   -1,
#   7,
#   22,
#   22,
#   2,
#   3,
#   -1,
#   5,
#   0,
#   9,
#   -1,
#   0,
#   12,
#   -1,
#   1,
#   21,
#   2,
#   20,
#   32,
#   7,
#   9,
#   9,
#   40,
#   17,
#   22,
#   23,
#   3,
#   28,
#   0,
#   -1,
#   -1,
#   8,
#   11,
#   0,
#   0,
#   0,
#   11,
#   0,
#   7,
#   14,
#   1,
#   3,
#   -1,
#   1,
#   5,
#   11,
#   21,
#   24,
#   34,
#   32,
#   18,
#   1,
#   -1,
#   24,
#   32,
#   14,
#   22,
#   19,
#   -1,
#   0,
#   36,
#   28,
#   11,
#   28,
#   23,
#   -1,
#   21,
#   7,
#   0,
#   -1,
#   4,
#   1,
#   19,
#   0,
#   -1,
#   10,
#   0,
#   0,
#   20,
#   0,
#   20,
#   7,
#   3,
#   32,
#   -1,
#   -1,
#   17,
#   1,
#   -1,
#   8,
#   -1,
#   23,
#   -1,
#   7,
#   27,
#   35,
#   0,
#   22,
#   -1,
#   18,
#   14,
#   16,
#   34,
#   1,
#   36,
#   14,
#   -1,
#   0,
#   0,
#   15,
#   28,
#   28,
#   0,
#   7,
#   7,
#   7,
#   3,
#   6,
#   1,
#   29,
#   0,
#   0,
#   34,
#   34,
#   7,
#   14,
#   0,
#   0,
#   0,
#   3,
#   0,
#   2,
#   24,
#   34,
#   30,
#   1,
#   9,
#   1,
#   0,
#   29,
#   4,
#   21,
#   4,
#   3,
#   3,
#   0,
#   23,
#   3,
#   7,
#   11,
#   5,
#   18,
#   1,
#   -1,
#   26,
#   1,
#   15,
#   0,
#   10,
#   20,
#   -1,
#   7,
#   13,
#   24,
#   25,
#   10,
#   8,
#   0,
#   0,
#   3,
#   24,
#   28,
#   22,
#   24,
#   1,
#   5,
#   24,
#   14,
#   9,
#   29,
#   11,
#   0,
#   0,
#   14,
#   9,
#   3,
#   0,
#   1,
#   1,
#   0,
#   0,
#   -1,
#   13,
#   1,
#   30,
#   35,
#   5,
#   1,
#   25,
#   3,
#   7,
#   11,
#   3,
#   1,
#   0,
#   -1,
#   0,
#   21,
#   29,
#   2,
#   11,
#   -1,
#   -1,
#   -1,
#   -1,
#   11,
#   28,
#   30,
#   15,
#   24,
#   5,
#   22,
#   1,
#   9,
#   1,
#   5,
#   0,
#   34,
#   1,
#   0,
#   0,
#   15,
#   13,
#   3,
#   36,
#   4,
#   32,
#   27,
#   0,
#   36,
#   0,
#   -1,
#   40,
#   0,
#   5,
#   5,
#   22,
#   0,
#   -1,
#   -1,
#   3,
#   13,
#   11,
#   29,
#   33,
#   2,
#   3,
#   22,
#   34,
#   -1,
#   0,
#   0,
#   22,
#   0,
#   9,
#   0,
#   -1,
#   12,
#   0,
#   24,
#   0,
#   7,
#   2,
#   0,
#   2,
#   -1,
#   23,
#   10,
#   34,
#   7,
#   2,
#   2,
#   25,
#   1,
#   14,
#   13,
#   3,
#   -1,
#   0,
#   4,
#   1,
#   30,
#   7,
#   0,
#   32,
#   13,
#   2,
#   8,
#   2,
#   3,
#   15,
#   -1,
#   3,
#   21,
#   0,
#   14,
#   1,
#   -1,
#   15,
#   5,
#   0,
#   5,
#   -1,
#   33,
#   -1,
#   5,
#   36,
#   9,
#   3,
#   -1,
#   0,
#   22,
#   29,
#   -1,
#   -1,
#   -1,
#   11,
#   0,
#   14,
#   21,
#   0,
#   13,
#   16,
#   -1,
#   36,
#   ...],
#  'topic_info': '{"Topic":{"0":-1,"1":0,"2":1,"3":2,"4":3,"5":4,"6":5,"7":6,"8":7,"9":8,"10":9,"11":10,"12":11,"13":12,"14":13,"15":14,"16":15,"17":16,"18":17,"19":18,"20":19,"21":20,"22":21,"23":22,"24":23,"25":24,"26":25,"27":26,"28":27,"29":28,"30":29,"31":30,"32":31,"33":32,"34":33,"35":34,"36":35,"37":36,"38":37,"39":38,"40":39,"41":40,"42":41},"Count":{"0":536,"1":561,"2":379,"3":119,"4":117,"5":115,"6":102,"7":100,"8":93,"9":92,"10":87,"11":85,"12":76,"13":76,"14":76,"15":73,"16":71,"17":70,"18":63,"19":61,"20":61,"21":60,"22":60,"23":58,"24":56,"25":56,"26":54,"27":51,"28":47,"29":46,"30":43,"31":39,"32":36,"33":36,"34":35,"35":34,"36":33,"37":33,"38":33,"39":33,"40":33,"41":31,"42":30},"Name":{"0":"-1_publicidad enga\\u00f1osa_demora env\\u00edo pedido_demora env\\u00edo_env\\u00edo pedido","1":"0_wallmart falta_parte wallmart_respuesta parte wallmart_falta respuesta","2":"1_lider mala_parte lider_lider falta_lider mala experiencia","3":"2_wallmart problemas_wallmart problemas pedido_aplicaci\\u00f3n wallmart problemas_problemas aplicaci\\u00f3n wallmart","4":"3_devoluci\\u00f3n dinero compra_dinero compra_dinero compra no_compra no","5":"4_devoluci\\u00f3n dinero devoluci\\u00f3n_dinero devoluci\\u00f3n dinero_dinero devoluci\\u00f3n_devoluci\\u00f3n dinero","6":"5_wallmart mala experiencia_compra wallmart mala_wallmart mala_experiencia compra wallmart","7":"6_solicitud ayuda_wallmart solicitud ayuda_wallmart solicitud_solicitud ayuda pedido","8":"7_wallmart servicio_cliente wallmart servicio_wallmart servicio cliente_servicio cliente wallmart","9":"8_pedido demora entrega_entrega pedido demora_pedido demora_demora entrega","10":"9_wallmart experiencia compra_wallmart experiencia_walmart experiencia compra_experiencia compra l\\u00ednea","11":"10_lider calidad_productos lider calidad_lider calidad productos_l\\u00edder calidad","12":"11_reclamo retraso_reclamo retraso entrega_reclamo demora_pedido reclamo retraso","13":"12_problemas puntos_l\\u00ednea problemas_problemas pedido problemas_problemas puntos club","14":"13_wallmart devoluci\\u00f3n_devoluci\\u00f3n dinero parte_dinero parte wallmart_reclamo producto no","15":"14_reclamo compra no_producto defectuoso_reclamo compra_defectuoso reclamo","16":"15_productos wallmart calidad_wallmart calidad productos_calidad productos wallmart_wallmart calidad","17":"16_pol\\u00edticas devoluci\\u00f3n_wallmart informaci\\u00f3n_informaci\\u00f3n pol\\u00edticas_informaci\\u00f3n pol\\u00edticas devoluci\\u00f3n","18":"17_devoluci\\u00f3n producto devoluci\\u00f3n_producto devoluci\\u00f3n_dinero producto no_devoluci\\u00f3n producto","19":"18_productos vencidos_producto vencido_reclamo producto vencido_fecha vencimiento","20":"19_web wallmart_web wallmart problemas_p\\u00e1gina web wallmart_problemas p\\u00e1gina","21":"20_reclamo falta entrega_falta entrega_falta entrega pedido_entrega pedido reclamo","22":"21_wallmart horario_apertura wallmart_horario apertura_wallmart horarios","23":"22_servicio wallmart calidad_calidad servicio wallmart_wallmart calidad servicio_calidad servicio","24":"23_solicitud boleta_boleta compra_solicitud boleta compra_boleta compra solicitud","25":"24_wallmart disponibilidad_disponibilidad productos_wallmart disponibilidad productos_productos disponibilidad","26":"25_productos calidad productos_productos calidad_productos belleza_salud seguridad","27":"26_cliente mala_cliente mala atenci\\u00f3n_atenci\\u00f3n cliente mala_mala atenci\\u00f3n cliente","28":"27_wallmart calidad productos_productos wallmart calidad_calidad productos wallmart_wallmart calidad","29":"28_consulta pedido_consulta pedido consulta_pedido consulta_consulta solicitud","30":"29_walmart calidad_productos walmart calidad_walmart calidad productos_calidad productos walmart","31":"30_promociones wallmart_promociones wallmart promociones_wallmart promociones wallmart_wallmart promociones","32":"31_compra compra_compra compra compra_env\\u00edo gratuito_env\\u00edo gratis","33":"3 ...

# %%
import pandas as pd
pd.read_json('json_data.json')

# %%
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
STOPWORDS = list(stopwords.words("spanish"))

# %%
relevant = {"no", "ni", "sin", "nada", "sí", "estad", "fuera"}
[STOPWORDS.remove(word) for word in relevant]

# %%
if 'sin' in STOPWORDS:
    print("sin is in the list")
